# %% [markdown]
# # look at driving_log.csv

# %%
# imports
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from sklearn.utils import shuffle
# %matplotlib inline

# %%
# globals
# FILE_DIR = 'data/'
FILE_DIR = '../data2/'
LOG_FILE = 'driving_log.csv'
# CORRECTED_PATH = 'data/IMG/'
CORRECTED_PATH = '../data2/IMG/'
SHEAR_SETTING = 100

# %%
# open the csv file
df = pd.read_csv(FILE_DIR+LOG_FILE)
df.head(1)
# Out:
#                                          center  \
# 0  data2/IMG/center_2018_03_14_18_26_47_540.jpg
#
#                                          left  \
# 0  data2/IMG/left_2018_03_14_18_26_47_540.jpg
#
#                                          right  steering  speed  a         b
# 0  data2/IMG/right_2018_03_14_18_26_47_540.jpg       0.0    0.0  0  6.325135

# %%
# let's look at steering stats
df['steering'].describe(percentiles=[0.25,0.5,0.75,0.8,0.9,0.95,0.99])
# Out:
# count    243.000000
# mean      -0.186673
# std        0.295291
# min       -1.000000
# 25%       -0.262583
# 50%        0.000000
# 75%        0.000000
# 80%        0.000000
# 90%        0.000000
# 95%        0.000000
# 99%        0.108106
# max        0.350000
# Name: steering, dtype: float64

# %%
# ok let's histogram it
plt.hist(df['steering'],bins=40)
plt.show()

# %%
# lot's of 0 angles?
print('zero angles: {0} from total:  {1}'.format(df[df['steering'] == 0].shape, df.shape))
# Out:
# zero angles: (134, 7) from total:  (243, 7)

# %%
# ok let's try some transformations
def normalise_img(img):
    """ x / 255 -1 """
    return (img / 255 - 1)

def flip_image(img, angle):
    """ 
        apply a horizontal flip transformation
        adjust angle for flip
    """
    return cv2.flip(img, 1), angle * -1


def shear_image(img, angle):
    h, w, c = img.shape
    
    pts1 = np.float32([[50,50],[140,50],[50,200]])
    pts2 = np.float32([[75,75],[140,50],[75,220]])
    
    angle = angle - 2 * .2
    
    M = cv2.getAffineTransform(pts1,pts2)

    return cv2.warpAffine(img,M,(w,h)), angle
    
def warp_image(img, angle):
    h, w, c = img.shape
    
    WIDTH_SHIFT_RANGE = 100
    HEIGHT_SHIFT_RANGE = 40

    
    # Translation
    tx = WIDTH_SHIFT_RANGE * np.random.uniform() - WIDTH_SHIFT_RANGE / 2
    ty = HEIGHT_SHIFT_RANGE * np.random.uniform() - HEIGHT_SHIFT_RANGE / 2
    angle = angle + tx / WIDTH_SHIFT_RANGE * 2 * .2
    
    transform_matrix = np.float32([[1, 0, tx],
                                   [0, 1, ty]])
    
    warped_image = cv2.warpAffine(img, transform_matrix, (w, h))
    return warped_image, angle

def resize_image(img):
    cropped_img = img[img.shape[0]-75:img.shape[0]-25, 0:img.shape[1]]
    return cv2.resize(cropped_img, (200, 66), interpolation=cv2.INTER_AREA) 

def get_points(img, angle):
    angle = 1.5708 * angle - 1.5708
    pt1 = (np.int_(np.floor(img.shape[1]/2)),img.shape[0])
    pt2 = (np.int_(np.floor(pt1[0] + (50 * np.cos(angle)))),np.int_(np.floor(pt1[1] + (50 * np.sin(angle)))))
    return pt1, pt2

# %%
img_path = CORRECTED_PATH+df.iloc[20][0].split('/')[-1]
img_angle = df.iloc[20][3]
print(img_path, img_angle)
img = cv2.imread(img_path)
#img = normalise_img(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
img = normalise_img(img)
plt.imshow(img)
plt.show()
# Out:
# ../data2/IMG/center_2018_03_14_18_26_49_242.jpg 0.0

# %%
img_path = CORRECTED_PATH+df.iloc[2][0].split('/')[-1]
img_angle = df.iloc[2][3]
print(img_path, img_angle)
# Out:
# ../data2/IMG/center_2018_03_14_18_26_47_706.jpg -0.4

# %%
img = cv2.imread(img_path)
plt.imshow(img)
plt.show()

# %%
img2 = normalise_img(img)
plt.imshow(img2)
plt.show()

# %%
img3, _ = flip_image(img, img_angle)
plt.imshow(img3)
plt.show()

# %%
img4, angle = shear_image(img, img_angle)
img4 = resize_image(img4)
pt1, pt2 = get_points(img4, angle)
print(pt1, pt2)
plt.imshow(cv2.line(img4, pt1, pt2, (255,0,0), thickness=2))
plt.title('warped steering angle: {0}'.format(angle))
plt.show()
# Out:
# (100, 66) (52, 50)

# %%
img4, angle = warp_image(img, img_angle)
pt1, pt2 = get_points(img4, angle)
print(pt1, pt2)
plt.imshow(cv2.line(img4, pt1, pt2, (255,0,0), thickness=2))
plt.title('warped steering angle: {0}'.format(angle))
plt.show()
# Out:
# (160, 160) (122, 127)

# %%
img6 = resize_image(img4)
pt1, pt2 = get_points(img6, angle)
print(pt1, pt2)
plt.imshow(cv2.line(img6, pt1, pt2, (255,0,0), thickness=2))
plt.title('steering angle: {0}'.format(angle))
plt.show()
# Out:
# (100, 66) (62, 33)

# %%
# balance the angles
def get_balanced_data(X):
    angles = []
    for index, row in df.iterrows():
        choice = random.choice([('center',0), ('left',0.25), ('right',-0.25)])
        img_path = CORRECTED_PATH+row[choice[0]].split('/')[-1]
        img = cv2.imread(img_path)
        angle = row['steering']+choice[1]
        if row['steering'] == 0:
            # do something
            keep_prob = random.random()
            if keep_prob < 0.9:
                # get warped image 90% of time
                img, angle = warp_image(img, angle)
            angles.append(angle)
        else:
            prob_image = random.random()
            if prob_image < 0.3:
                img, angle = warp_image(img, angle)
            elif prob_image < 0.6:
                img, angle = flip_image(img, angle)
            angles.append(angle)

# %%
plt.hist(angles, bins=40)
#plt.hist(df['steering'], bins=40)
plt.title(len(angles))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d86b32222095> in <module>()
# ----> 1 plt.hist(angles, bins=40)
#       2 #plt.hist(df['steering'], bins=40)
#       3 plt.title(len(angles))
#       4 plt.show()
#
# NameError: name 'angles' is not defined

# %%
# look at a generator
def data_generator(X, batch_size=32):
    
    sample_size = len(X)
    
    while 1:
        shuffle(X)
        
        for offset in range(0, sample_size, batch_size):
            
            batch_samples = X[offset:offset+batch_size]
            
            X_train = []
            y_train = []
            
            for index, item in batch_samples.iterrows():
                # create data
                choice = random.choice([('center',0), ('left',0.25), ('right',-0.25)])
                img_path = CORRECTED_PATH+item[choice[0]].split('/')[-1]
                img = cv2.imread(img_path)
                angle = item['steering']+choice[1]
                if item['steering'] == 0:
                    # do something
                    keep_prob = random.random()
                    if keep_prob < 0.9:
                        # get warped image 90% of time
                        img, angle = warp_image(img, angle)
                else:
                    prob_image = random.random()
                    if prob_image < 0.3:
                        img, angle = warp_image(img, angle)
                    elif prob_image < 0.6:
                        img, angle = flip_image(img, angle)
            
                X_train.append(img)
                y_train.append(angle)
                
            yield shuffle(np.array(X_train), np.array(y_train))

# %%
iterator = data_generator(df, batch_size=144)

# %%
fig, ax = plt.subplots(12,12, figsize=(20,10))
r = 0
c = 0   
for item in iterator:
    for i in range(144):
        if c == 12:
            c = 0
            r += 1
        img = resize_image(normalise_img(item[0][i]))
        pt1, pt2 = get_points(img, item[1][i])
        ax[r,c].imshow(cv2.line(img, pt1, pt2, (255,0,0), thickness=2))
        c += 1
    plt.show()
    break

# %%
plt.hist(item[1])
plt.show()
